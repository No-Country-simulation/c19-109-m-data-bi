# %%
csvfilepath = "C:/Users/Usuario/Documents/NO COUNTRY/SIMULACION 1/Medicare Post-Acute Care and Hospice - by Geography & Provider/2022/"
csvfilename= "ry2024_pacpuf_main_2020_2022s.csv"

# %%
Diabcsvfilepath = "C:/Users/Usuario/Documents/NO COUNTRY/SIMULACION 1/Datos Diabetes/"
csvfilename= "diabetic_data.csv"

# %%
import numpy as np
import pandas as pd

# %%
Diabcsvfilepath+csvfilename
# Out:
# 'C:/Users/Usuario/Documents/NO COUNTRY/SIMULACION 1/Datos Diabetes/diabetic_data.csv'

# %%
datasetcsv= pd.read_csv(Diabcsvfilepath+csvfilename)

# %%
datasetcsv.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)      ?
# 1        149190     55629189        Caucasian  Female  [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3        500364     82442376        Caucasian    Male  [30-40)      ?
# 4         16680     42519267        Caucasian    Male  [40-50)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# 0                 1  ...          No      No                   No
# 1                 3  ...          No      Up                   No
# 2                 2  ...          No      No                   No
# 3                 2  ...          No      Up                   No
# 4                 1  ...          No  Steady                   No
#
#    glipizide-metformin  glimepiride-pioglitazone  metformin-rosiglitazone  \
# 0                   No                        No                       No
# 1                   No                        No                       No
# 2                   No                        No                       No
# 3                   No                        No                       No
# 4                   No                        No                       No
#
#    metformin-pioglitazone  change diabetesMed readmitted
# 0                      No      No          No         NO
# 1                      No      Ch         Yes        >30
# 2                      No      No         Yes         NO
# 3                      No      Ch         Yes         NO
# 4                      No      Ch         Yes         NO
#
# [5 rows x 50 columns]

# %%
datasetcsv= datasetcsv.drop(columns=['payer_code'])

# %%
datasetcsv= datasetcsv.drop(columns=['race'])

# %%
datasetcsv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101766 entries, 0 to 101765
# Data columns (total 48 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   encounter_id              101766 non-null  int64
#  1   patient_nbr               101766 non-null  int64
#  2   gender                    101766 non-null  object
#  3   age                       101766 non-null  object
#  4   weight                    101766 non-null  object
#  5   admission_type_id         101766 non-null  int64
#  6   discharge_disposition_id  101766 non-null  int64
#  7   admission_source_id       101766 non-null  int64
#  8   time_in_hospital          101766 non-null  int64
#  9   medical_specialty         101766 non-null  object
#  10  num_lab_procedures        101766 non-null  int64
#  11  num_procedures            101766 non-null  int64
#  12  num_medications           101766 non-null  int64
#  13  number_outpatient         101766 non-null  int64
#  14  number_emergency          101766 non-null  int64
#  15  number_inpatient          101766 non-null  int64
#  16  diag_1                    101766 non-null  object
#  17  diag_2                    101766 non-null  object
#  18  diag_3                    101766 non-null  object
#  19  number_diagnoses          101766 non-null  int64
#  20  max_glu_serum             5346 non-null    object
#  21  A1Cresult                 17018 non-null   object
#  22  metformin                 101766 non-null  object
#  23  repaglinide               101766 non-null  object
#  24  nateglinide               101766 non-null  object
#  25  chlorpropamide            101766 non-null  object
#  26  glimepiride               101766 non-null  object
#  27  acetohexamide             101766 non-null  object
#  28  glipizide                 101766 non-null  object
#  29  glyburide                 101766 non-null  object
#  30  tolbutamide               101766 non-null  object
#  31  pioglitazone              101766 non-null  object
#  32  rosiglitazone             101766 non-null  object
#  33  acarbose                  101766 non-null  object
#  34  miglitol                  101766 non-null  object
#  35  troglitazone              101766 non-null  object
#  36  tolazamide                101766 non-null  object
#  37  examide                   101766 non-null  object
#  38  citoglipton               101766 non-null  object
#  39  insulin                   101766 non-null  object
#  40  glyburide-metformin       101766 non-null  object
#  41  glipizide-metformin       101766 non-null  object
#  42  glimepiride-pioglitazone  101766 non-null  object
#  43  metformin-rosiglitazone   101766 non-null  object
#  44  metformin-pioglitazone    101766 non-null  object
#  45  change                    101766 non-null  object
#  46  diabetesMed               101766 non-null  object
#  47  readmitted                101766 non-null  object
# dtypes: int64(13), object(35)
# memory usage: 37.3+ MB

# %%
datasetcsv['gender']=datasetcsv['gender'].apply(lambda x: 1 if x == 'Male' else 0)

# %%
datasetcsv['age']=datasetcsv['age'].apply(lambda x: 10 if x == '[0-10)' else x)
datasetcsv['age']=datasetcsv['age'].apply(lambda x: 20 if x == '[10-20)' else x)
datasetcsv['age']=datasetcsv['age'].apply(lambda x: 30 if x == '[20-30)' else x)
datasetcsv['age']=datasetcsv['age'].apply(lambda x: 40 if x == '[30-40)' else x)
datasetcsv['age']=datasetcsv['age'].apply(lambda x: 50 if x == '[40-50)' else x)
datasetcsv['age']=datasetcsv['age'].apply(lambda x: 60 if x == '[50-60)' else x)
datasetcsv['age']=datasetcsv['age'].apply(lambda x: 70 if x == '[60-70)' else x)
datasetcsv['age']=datasetcsv['age'].apply(lambda x: 80 if x == '[70-80)' else x)
datasetcsv['age']=datasetcsv['age'].apply(lambda x: 90 if x == '[80-90)' else x)
datasetcsv['age']=datasetcsv['age'].apply(lambda x: 100 if x == '[90-100)' else x)

# %%
datasetcsv['weight']=datasetcsv['weight'].apply(lambda x: 0 if x == '?' else x)

# %%
datasetcsv['weight']=datasetcsv['weight'].apply(lambda x: 25 if x == '[0-25)' else x)
datasetcsv['weight']=datasetcsv['weight'].apply(lambda x: 50 if x == '[25-50)' else x)
datasetcsv['weight']=datasetcsv['weight'].apply(lambda x: 75 if x == '[50-75)' else x)
datasetcsv['weight']=datasetcsv['weight'].apply(lambda x: 100 if x == '[75-100)' else x)
datasetcsv['weight']=datasetcsv['weight'].apply(lambda x: 125 if x == '[100-125)' else x)
datasetcsv['weight']=datasetcsv['weight'].apply(lambda x: 150 if x == '[125-150)' else x)
datasetcsv['weight']=datasetcsv['weight'].apply(lambda x: 175 if x == '[150-175)' else x)
datasetcsv['weight']=datasetcsv['weight'].apply(lambda x: 200 if x == '[175-200)' else x)
datasetcsv['weight']=datasetcsv['weight'].apply(lambda x: 250 if x == '>200' else x)

# %%
datasetcsv['readmitted']=datasetcsv['readmitted'].apply(lambda x: 1 if x == '<30' else 0)

# %%
datasetcsv.head(100)
# Out:
#     encounter_id  patient_nbr  gender  age  weight  admission_type_id  \
# 0        2278392      8222157       0   10       0                  6
# 1         149190     55629189       0   20       0                  1
# 2          64410     86047875       0   30       0                  1
# 3         500364     82442376       1   40       0                  1
# 4          16680     42519267       1   50       0                  1
# ..           ...          ...     ...  ...     ...                ...
# 95       1195056     79549353       1   80       0                  2
# 96       1195548    106343838       0   80       0                  1
# 97       1212006     84981816       1   80       0                  1
# 98       1257282     84488562       0   60       0                  1
# 99       1260216     92117574       1   40       0                  2
#
#     discharge_disposition_id  admission_source_id  time_in_hospital  \
# 0                         25                    1                 1
# 1                          1                    7                 3
# 2                          1                    7                 2
# 3                          1                    7                 2
# 4                          1                    7                 1
# ..                       ...                  ...               ...
# 95                         1                    2                 1
# 96                         3                    7                 5
# 97                         1                    7                 3
# 98                         1                    7                 2
# 99                         6                    4                 6
#
#            medical_specialty  ...  citoglipton  insulin  glyburide-metformin  \
# 0   Pediatrics-Endocrinology  ...           No       No                   No
# 1                          ?  ...           No       Up                   No
# 2                          ?  ...           No       No                   No
# 3                          ?  ...           No       Up                   No
# 4                          ?  ...           No   Steady                   No
# ..                       ...  ...          ...      ...                  ...
# 95                         ?  ...           No   Steady                   No
# 96    Family/GeneralPractice  ...           No   Steady                   No
# 97                         ?  ...           No     Down                   No
# 98           Surgery-General  ...           No       Up                   No
# 99                         ?  ...           No   Steady                   No
#
#     glipizide-metformin  glimepiride-pioglitazone  metformin-rosiglitazone  \
# 0                    No                        No                       No
# 1                    No                        No                       No
# 2                    No                        No                       No
# 3                    No                        No                       No
# 4                    No                        No                       No
# ..                  ...                       ...                      ...
# 95                   No                        No                       No
# 96                   No                        No                       No
# 97                   No                        No                       No
# 98                   No                        No                       No
# 99                   No                        No                       No
#
#    metformin-pioglitazone change diabetesMed  readmitted
# 0                      No     No          No           0
# 1                      No     Ch         Yes           0
# 2                      No     No         Yes           0
# 3                      No     Ch         Yes           0
# 4                      No     Ch         Yes           0
# ..                    ...    ...         ...         ...
# 95                     No     No         Yes           0
# 96                     No     No         Yes           0
# 97                     No     Ch         Yes           0
# 98                     No     Ch         Yes           0
# 99                     No     Ch         Yes           0
#
# [100 rows x 48 columns]

# %%
datasetcsv.describe()
# Out:
#        encounter_id   patient_nbr         gender            age  \
# count  1.017660e+05  1.017660e+05  101766.000000  101766.000000
# mean   1.652016e+08  5.433040e+07       0.462384      70.967022
# std    1.026403e+08  3.869636e+07       0.498586      15.940838
# min    1.252200e+04  1.350000e+02       0.000000      10.000000
# 25%    8.496119e+07  2.341322e+07       0.000000      60.000000
# 50%    1.523890e+08  4.550514e+07       0.000000      70.000000
# 75%    2.302709e+08  8.754595e+07       1.000000      80.000000
# max    4.438672e+08  1.895026e+08       1.000000     100.000000
#
#               weight  admission_type_id  discharge_disposition_id  \
# count  101766.000000      101766.000000             101766.000000
# mean        3.103935           2.024006                  3.715642
# std        17.850152           1.445403                  5.280166
# min         0.000000           1.000000                  1.000000
# 25%         0.000000           1.000000                  1.000000
# 50%         0.000000           1.000000                  1.000000
# 75%         0.000000           3.000000                  4.000000
# max       250.000000           8.000000                 28.000000
#
#        admission_source_id  time_in_hospital  num_lab_procedures  \
# count        101766.000000     101766.000000       101766.000000
# mean              5.754437          4.395987           43.095641
# std               4.064081          2.985108           19.674362
# min               1.000000          1.000000            1.000000
# 25%               1.000000          2.000000           31.000000
# 50%               7.000000          4.000000           44.000000
# 75%               7.000000          6.000000           57.000000
# max              25.000000         14.000000          132.000000
#
#        num_procedures  num_medications  number_outpatient  number_emergency  \
# count   101766.000000    101766.000000      101766.000000     101766.000000
# mean         1.339730        16.021844           0.369357          0.197836
# std          1.705807         8.127566           1.267265          0.930472
# min          0.000000         1.000000           0.000000          0.000000
# 25%          0.000000        10.000000           0.000000          0.000000
# 50%          1.000000        15.000000           0.000000          0.000000
# 75%          2.000000        20.000000           0.000000          0.000000
# max          6.000000        81.000000          42.000000         76.000000
#
#        number_inpatient  number_diagnoses     readmitted
# count     101766.000000     101766.000000  101766.000000
# mean           0.635566          7.422607       0.111599
# std            1.262863          1.933600       0.314874
# min            0.000000          1.000000       0.000000
# 25%            0.000000          6.000000       0.000000
# 50%            0.000000          8.000000       0.000000
# 75%            1.000000          9.000000       0.000000
# max           21.000000         16.000000       1.000000

# %%
import seaborn as sns

# %%
XVar= "num_lab_procedures"
YVar= "num_procedures"

# %%
sns.relplot(
    data=datasetcsv,
    x=XVar, y=YVar, hue="readmitted"    
)
# Out:
# c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
XVar= "time_in_hospital"
YVar= "num_medications"
sns.relplot(
    data=datasetcsv,
    x=XVar, y=YVar, hue="readmitted"    
)
# Out:
# c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
XVar= "time_in_hospital"
YVar= "number_diagnoses"
sns.relplot(
    data=datasetcsv,
    x=XVar, y=YVar, hue="readmitted"    
)
# Out:
# c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
XVar= "time_in_hospital"
YVar= "number_emergency"
sns.relplot(
    data=datasetcsv,
    x=XVar, y=YVar, hue="readmitted"    
)
# Out:
# c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
datasetcsv.hist()
# Out:
# array([[<Axes: title={'center': 'encounter_id'}>,
#         <Axes: title={'center': 'patient_nbr'}>,
#         <Axes: title={'center': 'admission_type_id'}>,
#         <Axes: title={'center': 'discharge_disposition_id'}>],
#        [<Axes: title={'center': 'admission_source_id'}>,
#         <Axes: title={'center': 'time_in_hospital'}>,
#         <Axes: title={'center': 'num_lab_procedures'}>,
#         <Axes: title={'center': 'num_procedures'}>],
#        [<Axes: title={'center': 'num_medications'}>,
#         <Axes: title={'center': 'number_outpatient'}>,
#         <Axes: title={'center': 'number_emergency'}>,
#         <Axes: title={'center': 'number_inpatient'}>],
#        [<Axes: title={'center': 'number_diagnoses'}>, <Axes: >, <Axes: >,
#         <Axes: >]], dtype=object)

# %%
from sqlalchemy import create_engine

db_file = 'diabetes.db'

engine = create_engine(f'sqlite:///{db_file}')

datasetcsv.to_sql('encounters', engine, index=False, if_exists='replace')
# Out:
# 101766

# %%
import matplotlib.pyplot as plt

# %%
ReadmissionsPerGender= datasetcsv[['gender','readmitted']]

# %%
ReadmissionsPerGender['gender']=ReadmissionsPerGender['gender'].apply(lambda x: 1 if x == 'Male' else 0)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_26792\1361302244.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ReadmissionsPerGender['gender']=ReadmissionsPerGender['gender'].apply(lambda x: 1 if x == 'Male' else 0)

# %%
ReadmissionsPerGender.loc[ReadmissionsPerGender['readmitted'] == 'NO','readmitted'] = 0

# %%
ReadmissionsPerGender.loc[ReadmissionsPerGender['readmitted'] == '>30','readmitted'] = 0

# %%
ReadmissionsPerGender.loc[ReadmissionsPerGender['readmitted'] != 0 ,'readmitted'] = 1

# %%
R= ReadmissionsPerGender[ReadmissionsPerGender['readmitted']== 1]
NR = ReadmissionsPerGender[ReadmissionsPerGender['readmitted']== 0]

# %%
R.hist()
NR.hist()
plt.show()

# %%
DF1=datasetcsv[['encounter_id','time_in_hospital' ,'readmitted']]

# %%
DFNR= DF1[(DF1['readmitted']=='NO') | (DF1['readmitted']=='>30')]

# %%
DFR= DF1[(DF1['readmitted']!='NO') & (DF1['readmitted']!='>30')]

# %%
DFNR
# Out:
#         encounter_id  time_in_hospital readmitted
# 0            2278392                 1         NO
# 1             149190                 3        >30
# 2              64410                 2         NO
# 3             500364                 2         NO
# 4              16680                 1         NO
# ...              ...               ...        ...
# 101761     443847548                 3        >30
# 101762     443847782                 5         NO
# 101763     443854148                 1         NO
# 101764     443857166                10         NO
# 101765     443867222                 6         NO
#
# [90409 rows x 3 columns]

# %%
plt.scatter(DFNR['encounter_id'],DFNR['time_in_hospital'])
plt.scatter(DFR['encounter_id'],DFR['time_in_hospital'])
plt.show()

# %%
db_name = "diabetes.db"
table_name = "encounters"

#engine = create_engine("sqlite:///%s" % db_name, execution_options={"sqlite_raw_colnames": True})
df = pd.read_sql_table(table_name, engine)

# %%
df
# Out:
#         encounter_id  patient_nbr             race  gender      age weight  \
# 0            2278392      8222157        Caucasian  Female   [0-10)      ?
# 1             149190     55629189        Caucasian  Female  [10-20)      ?
# 2              64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3             500364     82442376        Caucasian    Male  [30-40)      ?
# 4              16680     42519267        Caucasian    Male  [40-50)      ?
# ...              ...          ...              ...     ...      ...    ...
# 101761     443847548    100162476  AfricanAmerican    Male  [70-80)      ?
# 101762     443847782     74694222  AfricanAmerican  Female  [80-90)      ?
# 101763     443854148     41088789        Caucasian    Male  [70-80)      ?
# 101764     443857166     31693671        Caucasian  Female  [80-90)      ?
# 101765     443867222    175429310        Caucasian    Male  [70-80)      ?
#
#         admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                       6                        25                    1
# 1                       1                         1                    7
# 2                       1                         1                    7
# 3                       1                         1                    7
# 4                       1                         1                    7
# ...                   ...                       ...                  ...
# 101761                  1                         3                    7
# 101762                  1                         4                    5
# 101763                  1                         1                    7
# 101764                  2                         3                    7
# 101765                  1                         1                    7
#
#         time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# 0                      1  ...          No      No                   No
# 1                      3  ...          No      Up                   No
# 2                      2  ...          No      No                   No
# 3                      2  ...          No      Up                   No
# 4                      1  ...          No  Steady                   No
# ...                  ...  ...         ...     ...                  ...
# 101761                 3  ...          No    Down                   No
# 101762                 5  ...          No  Steady                   No
# 101763                 1  ...          No    Down                   No
# 101764                10  ...          No      Up                   No
# 101765                 6  ...          No      No                   No
#
#         glipizide-metformin  glimepiride-pioglitazone  \
# 0                        No                        No
# 1                        No                        No
# 2                        No                        No
# 3                        No                        No
# 4                        No                        No
# ...                     ...                       ...
# 101761                   No                        No
# 101762                   No                        No
# 101763                   No                        No
# 101764                   No                        No
# 101765                   No                        No
#
#         metformin-rosiglitazone  metformin-pioglitazone  change diabetesMed  \
# 0                            No                      No      No          No
# 1                            No                      No      Ch         Yes
# 2                            No                      No      No         Yes
# 3                            No                      No      Ch         Yes
# 4                            No                      No      Ch         Yes
# ...                         ...                     ...     ...         ...
# 101761                       No                      No      Ch         Yes
# 101762                       No                      No      No         Yes
# 101763                       No                      No      Ch         Yes
# 101764                       No                      No      Ch         Yes
# 101765                       No                      No      No          No
#
#        readmitted
# 0              NO
# 1             >30
# 2              NO
# 3              NO
# 4              NO
# ...           ...
# 101761        >30
# 101762         NO
# 101763         NO
# 101764         NO
# 101765         NO
#
# [101766 rows x 50 columns]

# %%
datasetcsv.to_sql('cleaned_data', engine, index=False, if_exists='replace')
# Out:
# 101766

# %%
import requests

# %%
myapikey= "1HE29SBOPsPISCJ40Wo4gV1bQE1nyFvgVPvkaEvI05Q"
myhost="cqzdwoclsz"
mydatabase="diabetes.db"
#https://cqzdwoclsz.sqlite.cloud:8090/v2/functions/function-1
#sqlitehost= "sqlitecloud://"+myhost+".sqlite.cloud:8860/"+mydatabase+"?apikey="+myapikey
#"https://dashboard.sqlitecloud.io/projects/cqzdwoclsz/databases?apikey="+myapikey
#/tables?databaseName=diabetes.db&tableName=cleaned_data

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
import sqlitecloud
#conn = sqlitecloud.connect(sqlitehost)

HOST = "sqlitecloud://cqzdwoclsz.sqlite.cloud:8860?apikey=8ZBRx9VjOUr3L8r7arbcH8X27UpFfHwvq7qiaULwWdE"
HOST2="sqlitecloud://nmvvwo5liz.sqlite.cloud:8860?apikey=8ZBRx9VjOUr3L8r7arbcH8X27UpFfHwvq7qiaULwWdE"
conn = sqlitecloud.connect(HOST2)
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlitecloud\driver.py:184, in Driver._internal_connect(self, hostname, port, config)
#     183 try:
# --> 184     sock.connect((hostname, port))
#     185 except Exception as e:
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1379, in SSLSocket.connect(self, addr)
#    1377 """Connects to remote ADDR, and then wraps the connection in
#    1378 an SSL channel."""
# -> 1379 self._real_connect(addr, False)
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1370, in SSLSocket._real_connect(self, addr, connect_ex)
#    1369     if self.do_handshake_on_connect:
# -> 1370         self.do_handshake()
#    1371 return rc
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1346, in SSLSocket.do_handshake(self, block)
#    1345         self.settimeout(None)
# -> 1346     self._sslobj.do_handshake()
#    1347 finally:
#
# SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:992)
#
# The above exception was the direct cause of the following exception:
#
# SQLiteCloudException                      Traceback (most recent call last)
# Cell In[17], line 6
#       4 HOST = "sqlitecloud://cqzdwoclsz.sqlite.cloud:8860?apikey=8ZBRx9VjOUr3L8r7arbcH8X27UpFfHwvq7qiaULwWdE"
#       5 HOST2="sqlitecloud://nmvvwo5liz.sqlite.cloud:8860?apikey=8ZBRx9VjOUr3L8r7arbcH8X27UpFfHwvq7qiaULwWdE"
# ----> 6 conn = sqlitecloud.connect(HOST2)
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlitecloud\dbapi2.py:109, in connect(connection_info, config)
#     105 else:
#     106     config = SQLiteCloudConfig(connection_info)
#     108 return Connection(
# --> 109     driver.connect(config.account.hostname, config.account.port, config)
#     110 )
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlitecloud\driver.py:53, in Driver.connect(self, hostname, port, config)
#      36 def connect(
#      37     self, hostname: str, port: int, config: SQLiteCloudConfig
#      38 ) -> SQLiteCloudConnect:
#      39     """
#      40     Connect to the SQLite Cloud server.
#      41
#    (...)
#      51         SQLiteCloudException: If an error occurs while connecting the socket.
#      52     """
# ---> 53     sock = self._internal_connect(hostname, port, config)
#      55     connection = SQLiteCloudConnect()
#      56     connection.config = config
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlitecloud\driver.py:187, in Driver._internal_connect(self, hostname, port, config)
#     185 except Exception as e:
#     186     errmsg = "An error occurred while initializing the socket."
# --> 187     raise SQLiteCloudException(errmsg) from e
#     189 return sock
#
# SQLiteCloudException: An error occurred while initializing the socket.
